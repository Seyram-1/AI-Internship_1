# %% [markdown]
# <a href="https://colab.research.google.com/github/Seyram-1/AI-Internship_1/blob/main/AI_internship_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2025-11-11 15:05:14--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.2’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   266MB/s    in 0.3s
#
# 2025-11-11 15:05:15 (266 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.2’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> pkgs/main/linux-64::certifi-2019.11.28-py37_0
#
# The following packages will be DOWNGRADED:
#
#   ca-certificates                      2025.11.4-h06a4308_0 --> 2020.1.1-0
#   openssl                                 1.1.1w-h7f8727e_0 --> 1.1.1d-h7b6447c_4
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2025.11.4-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2019.11.2~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1w-h7f8727e_0
#
#
# done
# done
# done

# %%
# Install RDKit
# !pip install rdkit-pypi
# Out:
# Requirement already satisfied: rdkit-pypi in /usr/local/lib/python3.7/site-packages (2022.9.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from rdkit-pypi) (1.21.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/site-packages (from rdkit-pypi) (8.2.0)

# %%
import pandas as pd

# %%
dataset = pd.read_excel('/content/Pubchem_data_SGLT2_03112025.xlsx')
dataset
# Out:
#     PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                    1    104153399     46889407
# 1                    2    104153400     46889427
# 2                    3    104153401     46889428
# 3                    4    104153402     46889429
# 4                    5    104153403     46889430
# ..                 ...          ...          ...
# 92                  93    172098306     49846153
# 93                  94    172098307     49846230
# 94                  95    172098308     49846231
# 95                  96    172098309     49846232
# 96                  97    172098310     49846233
#
#                         PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0   C1=CC(=C(C=C1[C@H]2[C@@H]([C@H]([C@@H]([C@H](O...
# 1   CCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([C...
# 2   CCCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([...
# 3   CC(C)OC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]...
# 4   CCCCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H](...
# ..                                                ...
# 92  COC1=C(C=C(C2=CC=CC=C21)[C@H]3[C@@H]([C@H]([C@...
# 93  C1=CC=C2C(=C1)C(=CC(=C2O)CC3=NN=C(S3)C4=CC=CO4...
# 94  C1=CC=C2C(=C1)C=C(C=C2CC3=NN=C(S3)C4=CC=CO4)[C...
# 95  C1=COC(=C1)C2=NN=C(S2)CC3=CC(=C(C=C3Cl)Cl)[C@H...
# 96  COC1=C(C=C(C(=C1)Cl)CC2=NN=C(S2)C3=CC=CO3)[C@H...
#
#    PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                    Active                     NaN                   NaN
# 1                    Active                     NaN                   NaN
# 2                    Active                     NaN                   NaN
# 3                    Active                     NaN                   NaN
# 4                    Active                     NaN                   NaN
# ..                      ...                     ...                   ...
# 92                   Active                     NaN                   NaN
# 93                   Active                     NaN                   NaN
# 94                   Active                     NaN                   NaN
# 95                   Active                     NaN                   NaN
# 96                   Active                     NaN                   NaN
#
#     PUBCHEM_ASSAYDATA_COMMENT Standard Type  PubChem Standard Value    IC50  \
# 0                         NaN          IC50                 0.20200  202.00
# 1                         NaN          IC50                 0.04300   43.00
# 2                         NaN          IC50                 0.07080   70.80
# 3                         NaN          IC50                 0.11000  110.00
# 4                         NaN          IC50                 0.10900  109.00
# ..                        ...           ...                     ...     ...
# 92                        NaN          IC50                 0.01070   10.70
# 93                        NaN          IC50                 0.02480   24.80
# 94                        NaN          IC50                 0.32300  323.00
# 95                        NaN          IC50                 0.01760   17.60
# 96                        NaN          IC50                 0.00555    5.55
#
#    Target Accession(s)        Ligand                          Target
# 0               P31639  BDBM50319038  Sodium/glucose cotransporter 2
# 1               P31639  BDBM50319039  Sodium/glucose cotransporter 2
# 2               P31639  BDBM50319040  Sodium/glucose cotransporter 2
# 3               P31639  BDBM50319041  Sodium/glucose cotransporter 2
# 4               P31639  BDBM50319042  Sodium/glucose cotransporter 2
# ..                 ...           ...                             ...
# 92              P31639    BDBM103015  Sodium/glucose cotransporter 2
# 93              P31639    BDBM103016  Sodium/glucose cotransporter 2
# 94              P31639    BDBM103017  Sodium/glucose cotransporter 2
# 95              P31639    BDBM103018  Sodium/glucose cotransporter 2
# 96              P31639    BDBM103019  Sodium/glucose cotransporter 2
#
# [97 rows x 14 columns]

# %%
display(dataset['PUBCHEM_EXT_DATASOURCE_SMILES'])
# Out:
# 0     C1=CC(=C(C=C1[C@H]2[C@@H]([C@H]([C@@H]([C@H](O...
# 1     CCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([C...
# 2     CCCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([...
# 3     CC(C)OC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]...
# 4     CCCCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H](...
#                             ...
# 92    COC1=C(C=C(C2=CC=CC=C21)[C@H]3[C@@H]([C@H]([C@...
# 93    C1=CC=C2C(=C1)C(=CC(=C2O)CC3=NN=C(S3)C4=CC=CO4...
# 94    C1=CC=C2C(=C1)C=C(C=C2CC3=NN=C(S3)C4=CC=CO4)[C...
# 95    C1=COC(=C1)C2=NN=C(S2)CC3=CC(=C(C=C3Cl)Cl)[C@H...
# 96    COC1=C(C=C(C(=C1)Cl)CC2=NN=C(S2)C3=CC=CO3)[C@H...
# Name: PUBCHEM_EXT_DATASOURCE_SMILES, Length: 97, dtype: object

# %%
mol_list = []
for element in dataset['PUBCHEM_EXT_DATASOURCE_SMILES']:
  mol = Chem.MolFromSmiles(element)
  mol_list.append(mol)

# %%
len(mol_list)
# Out:
# 97

# %%
from rdkit import Chem

# %%
Chem.MolFromSmiles(dataset['PUBCHEM_EXT_DATASOURCE_SMILES'][0])

# %%
mol_list= []
for element in dataset['PUBCHEM_EXT_DATASOURCE_SMILES']:
  mol = Chem.MolFromSmiles(element)
  mol_list.append(mol)

# %%
len(mol_list)
# Out:
# 97

# %%
import numpy as np

# %%
from rdkit.Chem import Descriptors

# %%
def generate(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_MolWt = Descriptors.MolWt(mol)
        desc_NumRotatableBonds = Descriptors.NumRotatableBonds(mol)

        row = np.array([desc_MolLogP,
                        desc_MolWt,
                        desc_NumRotatableBonds])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MolLogP","MolWt","NumRotatableBonds"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
df = generate(dataset['PUBCHEM_EXT_DATASOURCE_SMILES'])
df
# Out:
#     MolLogP    MolWt  NumRotatableBonds
# 0    0.8891  401.246                4.0
# 1    0.6344  410.854                6.0
# 2    1.0245  424.881                7.0
# 3    1.0229  424.881                6.0
# 4    1.4146  438.908                8.0
# ..      ...      ...                ...
# 92   2.0656  484.530                6.0
# 93   1.7626  470.503                5.0
# 94   2.0570  454.504                5.0
# 95   2.2106  473.334                5.0
# 96   1.5658  468.915                6.0
#
# [97 rows x 3 columns]

# %%
p = Chem.MolFromSmiles(dataset['PUBCHEM_EXT_DATASOURCE_SMILES'][0])

# %%
aromatic_atoms = [p.GetAtomWithIdx(i).GetIsAromatic() for i in range(p.GetNumAtoms())]
aromatic_atoms
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False]

# %%
def AromaticAtoms(p):
  aromatic_atoms = [p.GetAtomWithIdx(i).GetIsAromatic() for i in range(p.GetNumAtoms())]
  aa_count = []
  for i in aromatic_atoms:
    if i==True:
      aa_count.append(1)
  sum_aa_count = sum(aa_count)
  return sum_aa_count

# %%
AromaticAtoms(p)
# Out:
# 12

# %%
desc_AromaticAtoms = [AromaticAtoms(element) for element in mol_list]
desc_AromaticAtoms
# Out:
# [12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  18,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  18,
#  17,
#  17,
#  17,
#  17,
#  17,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  17,
#  17,
#  12,
#  12,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  21,
#  21,
#  17,
#  17,
#  16,
#  16,
#  16,
#  16,
#  22,
#  20,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  20,
#  16,
#  11,
#  11,
#  11,
#  11,
#  22,
#  17,
#  17,
#  17,
#  17,
#  11,
#  11,
#  17,
#  17,
#  17,
#  17,
#  12,
#  12,
#  12,
#  18,
#  16,
#  16,
#  12,
#  18,
#  12,
#  20,
#  20,
#  20,
#  20,
#  16,
#  16]

# %%
Descriptors.HeavyAtomCount(p)
# Out:
# 26

# %%
desc_HeavyAtomCount = [Descriptors.HeavyAtomCount(element) for element in mol_list]
desc_HeavyAtomCount
# Out:
# [26,
#  28,
#  29,
#  29,
#  30,
#  30,
#  31,
#  32,
#  32,
#  32,
#  27,
#  28,
#  32,
#  26,
#  27,
#  28,
#  28,
#  29,
#  29,
#  30,
#  33,
#  30,
#  30,
#  30,
#  30,
#  31,
#  31,
#  32,
#  33,
#  31,
#  34,
#  35,
#  30,
#  31,
#  31,
#  30,
#  28,
#  26,
#  26,
#  28,
#  29,
#  29,
#  30,
#  31,
#  30,
#  31,
#  31,
#  31,
#  34,
#  34,
#  30,
#  30,
#  29,
#  29,
#  30,
#  30,
#  35,
#  33,
#  30,
#  30,
#  29,
#  29,
#  30,
#  30,
#  30,
#  33,
#  29,
#  27,
#  28,
#  29,
#  31,
#  35,
#  30,
#  30,
#  31,
#  33,
#  30,
#  32,
#  33,
#  32,
#  29,
#  29,
#  29,
#  34,
#  27,
#  32,
#  30,
#  29,
#  25,
#  31,
#  28,
#  32,
#  34,
#  33,
#  32,
#  30,
#  31]

# %%
AromaticAtoms(p)/Descriptors.HeavyAtomCount(p)
# Out:
# 0.46153846153846156

# %%
desc_AromaticProportion = [AromaticAtoms(element)/Descriptors.HeavyAtomCount(element) for element in mol_list]
desc_AromaticProportion
# Out:
# [0.46153846153846156,
#  0.42857142857142855,
#  0.41379310344827586,
#  0.41379310344827586,
#  0.4,
#  0.4,
#  0.3870967741935484,
#  0.375,
#  0.375,
#  0.375,
#  0.4444444444444444,
#  0.42857142857142855,
#  0.5625,
#  0.46153846153846156,
#  0.4444444444444444,
#  0.42857142857142855,
#  0.42857142857142855,
#  0.41379310344827586,
#  0.41379310344827586,
#  0.4,
#  0.5454545454545454,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5483870967741935,
#  0.5806451612903226,
#  0.5625,
#  0.5454545454545454,
#  0.5806451612903226,
#  0.5294117647058824,
#  0.5142857142857142,
#  0.5666666666666667,
#  0.5483870967741935,
#  0.3870967741935484,
#  0.4,
#  0.42857142857142855,
#  0.4230769230769231,
#  0.4230769230769231,
#  0.39285714285714285,
#  0.3793103448275862,
#  0.3793103448275862,
#  0.5666666666666667,
#  0.5483870967741935,
#  0.5666666666666667,
#  0.5483870967741935,
#  0.5483870967741935,
#  0.5483870967741935,
#  0.6176470588235294,
#  0.6176470588235294,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5517241379310345,
#  0.5517241379310345,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6285714285714286,
#  0.6060606060606061,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.5517241379310345,
#  0.5517241379310345,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6060606060606061,
#  0.5517241379310345,
#  0.4074074074074074,
#  0.39285714285714285,
#  0.3793103448275862,
#  0.3548387096774194,
#  0.6285714285714286,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5483870967741935,
#  0.5151515151515151,
#  0.36666666666666664,
#  0.34375,
#  0.5151515151515151,
#  0.53125,
#  0.5862068965517241,
#  0.5862068965517241,
#  0.41379310344827586,
#  0.35294117647058826,
#  0.4444444444444444,
#  0.5625,
#  0.5333333333333333,
#  0.5517241379310345,
#  0.48,
#  0.5806451612903226,
#  0.42857142857142855,
#  0.625,
#  0.5882352941176471,
#  0.6060606060606061,
#  0.625,
#  0.5333333333333333,
#  0.5161290322580645]

# %%
df
# Out:
#     MolLogP    MolWt  NumRotatableBonds
# 0    0.8891  401.246                4.0
# 1    0.6344  410.854                6.0
# 2    1.0245  424.881                7.0
# 3    1.0229  424.881                6.0
# 4    1.4146  438.908                8.0
# ..      ...      ...                ...
# 92   2.0656  484.530                6.0
# 93   1.7626  470.503                5.0
# 94   2.0570  454.504                5.0
# 95   2.2106  473.334                5.0
# 96   1.5658  468.915                6.0
#
# [97 rows x 3 columns]

# %%
df_desc_AromaticProportion = pd.DataFrame(desc_AromaticProportion, columns=['AromaticProportion'])
df_desc_AromaticProportion
# Out:
#     AromaticProportion
# 0             0.461538
# 1             0.428571
# 2             0.413793
# 3             0.413793
# 4             0.400000
# ..                 ...
# 92            0.588235
# 93            0.606061
# 94            0.625000
# 95            0.533333
# 96            0.516129
#
# [97 rows x 1 columns]

# %%
X = pd.concat([df,df_desc_AromaticProportion], axis=1)
X
# Out:
#     MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0    0.8891  401.246                4.0            0.461538
# 1    0.6344  410.854                6.0            0.428571
# 2    1.0245  424.881                7.0            0.413793
# 3    1.0229  424.881                6.0            0.413793
# 4    1.4146  438.908                8.0            0.400000
# ..      ...      ...                ...                 ...
# 92   2.0656  484.530                6.0            0.588235
# 93   1.7626  470.503                5.0            0.606061
# 94   2.0570  454.504                5.0            0.625000
# 95   2.2106  473.334                5.0            0.533333
# 96   1.5658  468.915                6.0            0.516129
#
# [97 rows x 4 columns]

# %%
dataset.head()
# Out:
#    PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                   1    104153399     46889407
# 1                   2    104153400     46889427
# 2                   3    104153401     46889428
# 3                   4    104153402     46889429
# 4                   5    104153403     46889430
#
#                        PUBCHEM_EXT_DATASOURCE_SMILES PUBCHEM_ACTIVITY_OUTCOME  \
# 0  C1=CC(=C(C=C1[C@H]2[C@@H]([C@H]([C@@H]([C@H](O...                   Active
# 1  CCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([C...                   Active
# 2  CCCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([...                   Active
# 3  CC(C)OC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]...                   Active
# 4  CCCCOC1=NN=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H](...                   Active
#
#    PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  PUBCHEM_ASSAYDATA_COMMENT  \
# 0                     NaN                   NaN                        NaN
# 1                     NaN                   NaN                        NaN
# 2                     NaN                   NaN                        NaN
# 3                     NaN                   NaN                        NaN
# 4                     NaN                   NaN                        NaN
#
#   Standard Type  PubChem Standard Value   IC50 Target Accession(s)  \
# 0          IC50                  0.2020  202.0              P31639
# 1          IC50                  0.0430   43.0              P31639
# 2          IC50                  0.0708   70.8              P31639
# 3          IC50                  0.1100  110.0              P31639
# 4          IC50                  0.1090  109.0              P31639
#
#          Ligand                          Target
# 0  BDBM50319038  Sodium/glucose cotransporter 2
# 1  BDBM50319039  Sodium/glucose cotransporter 2
# 2  BDBM50319040  Sodium/glucose cotransporter 2
# 3  BDBM50319041  Sodium/glucose cotransporter 2
# 4  BDBM50319042  Sodium/glucose cotransporter 2

# %%
Y = dataset.iloc[: , 1]
Y
# Out:
# 0     104153399
# 1     104153400
# 2     104153401
# 3     104153402
# 4     104153403
#         ...
# 92    172098306
# 93    172098307
# 94    172098308
# 95    172098309
# 96    172098310
# Name: PUBCHEM_SID, Length: 97, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model_1 = linear_model.LinearRegression()
model_1.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_train = model_1.predict(X_train)

# %%
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_train, Y_pred_train))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_train, Y_pred_train))
# Out:
# Mean squared error (MSE): 900687533295987.62
# Coefficient of determination (R^2): 0.04

# %%
Y_pred_test = model_1.predict(X_test)

# %%
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred_test))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred_test))
# Out:
# Mean squared error (MSE): 756413279680928.50
# Coefficient of determination (R^2): -0.02

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_2 = RandomForestRegressor(n_estimators=100)
model_2.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred_train_rf = model_2.predict(X_train)

# %%
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_train, Y_pred_train_rf))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_train, Y_pred_train_rf))
# Out:
# Mean squared error (MSE): 110621099223544.25
# Coefficient of determination (R^2): 0.88

# %%
Y_pred_test_rf = model_2.predict(X_test)

# %%
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred_test_rf))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred_test_rf))
# Out:
# Mean squared error (MSE): 785842983478889.75
# Coefficient of determination (R^2): -0.06
